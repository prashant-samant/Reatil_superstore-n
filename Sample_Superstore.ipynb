# %% [markdown]
# # THE SPARK FOUNDATIONS - DATA SCIENCE AND BUISNESS ANALYTICS

# %% [markdown]
# # Task 1 : Retail  Superstore

# %% [markdown]
# A retail sale occurs when a business sells a product or service to an individual consumer for his or her own use. The transaction itself can occur through a number of different sales channels, such as online, in a brick-and-mortar storefront, through direct sales, or direct mail. The aspect of the sale that qualifies it as a retail transaction is that the end user is the buyer.

# %% [markdown]
# # Perform 'Exploratory Data Analysis' on dataset 'SampleSuperstore'

# %% [markdown]
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# To find out the weak areas where we can work to make more profit.

# %% [markdown]
# # Lets import the required Python libraries

# %%
import numpy as np #for numeric data 
import pandas as pd #for dataframe 
import matplotlib.pyplot as plt # for plots 
import seaborn as sns #for Advance plots 
import warnings

# %% [markdown]
# # Lets load the dataset

# %%
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# The dataset contains approximately 10 thousands rows and 13 columns

# %% [markdown]
# # Exploring the dataset

# %%
df.info()      # To know the datatypes of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# Lets check whether datatset contains any null or nan values or not.

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# As we can cleary see from the above that our dataset does not contains any null values, which is good for further analysis.

# %%
df.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370     2
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288     2
#                                             San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780     2
#                 Corporate    United States  Seattle        Washington  98105        West     Office Supplies  Paper         19.440   3         0.0        9.3312     2
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe(include = 'all')   #Statistical matrix
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %% [markdown]
# # Observations
#
# 1 . 'Standard Class' shipping mode is the top in order to deliver the products as compared to other shipping modes.
#
# 2 . New York is the only city and California is the only state of United States which are the top of retail buisness as compared to other cities and states.
#
# 3 . The average sales of the superstore is $ 229.85
# and it maximum goes upto $ 22638.
#
# 4 . The average profit that has been gained to superstore is $ 28.65.

# %% [markdown]
# # Lets visualize each column and generate the inferences from it.

# %% [markdown]
# # Univariate Analysis

# %%
fig, axis = plt.subplots(nrows = 2 , ncols = 2 , figsize = (10 , 10))
sns.countplot(data = df , x = df["Ship Mode"] , ax = axis[0 , 0])  
sns.countplot(data = df , x = df["Segment"] , ax = axis[0 , 1])  
sns.countplot(data = df , x = df["Region"] , ax = axis[1, 0])  
sns.countplot(data = df , x = df["Category"] , ax = axis[1, 1])   
plt.tight_layout()
plt.show()

# %%
df["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
fig, axis = plt.subplots(nrows = 2 , ncols = 2 , figsize = (10,10)) 
sns.boxplot(data = df , x = df['Sales'] ,  ax = axis[0,0] ,  color = "b")
sns.boxplot(data = df , x = df['Quantity'] ,  ax = axis[0,1] ,  color = 'r')
sns.boxplot(data = df , x = df['Discount'] ,  ax = axis[1,0] , color = 'g')
sns.boxplot(data = df , x = df['Profit'] ,  ax = axis[1,1] , color = 'y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observations
#
# 1 . It is observed from the above that the most occurred ship mode is 'Standard Class' as compared to other ship modes.
#
# 2 . Consumer is the highest occuring segment in the retail and it means that most of the products have been purchased by individual consumers as compared to other segments such as corporate or home offices.
#
# 3 . The highest number of sales took place in the west and east region of United States.
#
# 4 . The office supplies are more purchased as compared to other supplies such as furniture and technology.
#
# 5 . It is observed from the above that profit section have highest number of outliers. Consequently, retail store gained profit and loss simultaneously.

# %% [markdown]
# # Bivariate Analysis

# %%
pd.DataFrame(df.groupby('Ship Mode').sum()[['Sales','Profit']]).plot(kind='bar')
pd.DataFrame(df.groupby('Region').sum()[['Sales','Profit']]).plot(kind='bar')
pd.DataFrame(df.groupby('Segment').sum()[['Sales','Profit']]).plot(kind='bar')
pd.DataFrame(df.groupby('Category').sum()[['Sales','Profit']]).plot(kind='bar')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observations
#
# 1 . Standard Class shipping mode has the highest sales and profit in the superstore.
#
# 2 . West region has the highest sales and profit which is around $ 70k.
#
# 3 . The maximum profit and sales of technology are $ 80k.

# %% [markdown]
# # What are the best selling and most profitable sub-category?

# %%
df2 = pd.DataFrame(df.groupby(['Sub-Category'])[['Sales', 'Profit']].sum())

# Sort by descending order according to sales

subcat_df2 = pd.DataFrame(df2.sort_values('Sales', ascending = False))

subcat_df2
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        328449.1030  26590.1663
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203412.7330  30221.7633
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91705.1640  13059.1436
# Paper          78479.2060  34053.5693
# Supplies       46673.5380  -1189.0995
# Art            27118.7920   6527.7870
# Envelopes      16476.4020   6964.1767
# Labels         12486.3120   5546.2540
# Fasteners       3024.2800    949.5182

# %%
subcat_profit_df2 = pd.DataFrame(subcat_df2.sort_values('Profit', ascending = False))

subcat_profit_df2
# Out:
#                     Sales      Profit
# Sub-Category
# Copiers       149528.0300  55617.8249
# Phones        330007.0540  44515.7306
# Accessories   167380.3180  41936.6357
# Paper          78479.2060  34053.5693
# Binders       203412.7330  30221.7633
# Chairs        328449.1030  26590.1663
# Storage       223843.6080  21278.8264
# Appliances    107532.1610  18138.0054
# Furnishings    91705.1640  13059.1436
# Envelopes      16476.4020   6964.1767
# Art            27118.7920   6527.7870
# Labels         12486.3120   5546.2540
# Machines      189238.6310   3384.7569
# Fasteners       3024.2800    949.5182
# Supplies       46673.5380  -1189.0995
# Bookcases     114879.9963  -3472.5560
# Tables        206965.5320 -17725.4811

# %%
sns.set_theme(style="whitegrid")


figure, axis = plt.subplots(1, 2, figsize=(12, 6))

subcat1 = sns.barplot(data = subcat_df2, x = subcat_df2.index, y = subcat_df2.Sales, ax=axis[0], palette = "rainbow")
subcat1.set(title="Best Selling Sub-Category")
subcat1.set_xticklabels(subcat1.get_xticklabels(),rotation = "vertical", size = 10)

subcat2 = sns.barplot(data = subcat_profit_df2, x = subcat_profit_df2.index, y = subcat_profit_df2.Profit, ax=axis[1], palette = "coolwarm")
subcat2.set(title = "Most Profitable Sub-Category")
subcat2.set_xticklabels(subcat2.get_xticklabels(),rotation = "vertical", size = 10)

figure.tight_layout()
plt.show()

# %% [markdown]
# # Observations
#
#
# 1 . The best selling Sub-Category is Phones and chairs .
#
# 2 . Copiers are the most profitable Sub-Category and Tables are the most non-profitable Sub-Category.
#
# 3 . On the other end of the spectrum, Machines, Fasteners, Supplies, Bookcases and Tables make close to zero margin to losses. These are products that Super Store can consider dropping from the product catalogue or increase the sale price and profit margin or bargain for a lower price from the supplier.

# %% [markdown]
# # What are the most profitable region?

# %%
df5 = pd.DataFrame(df.groupby(['Region'])['Profit'].sum().reset_index())

df5
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
explode = [0, 0, 0, 0.1]
plt.pie(df5.Profit, labels = df5.Region, startangle = 360, autopct = "%1.0f%%", explode = explode, shadow = True)

plt.title("Most Profitable Region")

plt.show()

# %% [markdown]
# # What are the most profitable segment?

# %%
df6 = pd.DataFrame(df.groupby(['Segment'])['Profit'].sum().reset_index())

df6
# Out:
#        Segment       Profit
# 0     Consumer  134119.2092
# 1    Corporate   91979.1340
# 2  Home Office   60298.6785

# %%
explode = [0,0,0.1]
plt.pie(df6.Profit , explode = explode , labels = df6.Segment , startangle = 180 , autopct = "%1.0f%%" , shadow = True)
plt.title("Most Profitable Segment") 
plt.show()

# %% [markdown]
# # What are the most profitable category?

# %%
df6 = pd.DataFrame(df.groupby(['Category'])['Profit'].sum().reset_index())

df6
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %%
explode = [0,0,0.1] 
plt.pie(df6.Profit ,  explode = explode , labels = df6.Category , shadow = True , startangle = 180 , autopct = "%1.0f%%")
plt.title("Most Profitable Category")
plt.show()

# %% [markdown]
# # Observations
#
# 1 . As, we can clearly see from the above pie chart that West region is the most profitable region of United States and the profit amount is less in Central region.
#
# 2 . It is observed that the most profitable segment is consumer as compared to other sectors.
#
# 3 . In the Category section the highest profit is generated from the technology appliances.

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(12,6))
sns.set_theme(style="white")
corr = df.corr()
heatmap = sns.heatmap(corr, annot=True)

# %% [markdown]
# From above heatmap it is observed that Profits, Sales and Quantity columns have strong bond, which means any slight change in any of these will impact the business.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Recommendations
#
# 1 . Focus on Technology sub-category and Phones and Chairs as they are highest selling and most profitable. Bundle them with the less profitable products such as Bookcases, Table and Chairs to offset the losses.
#
# 2 . Bookcases and chairs are the sub-category of furniture , which showed the highest loss in the sub-category section. In order to increase the profit, Superstore should club bookcase and chairs with highest profitable products such as copiers and phones.
#
# 3 . The Central region showed 14% of profit which is less. However, in order to increase profit, the investors of superstore should open more number of stores in the central region of United States.
#
# 4 . For loss-making products like Supplies, Bookcases, Tables, consider to either drop these from the catalogue or change suppliers and bargain for cheaper price.
#
# 5 . The lowest profit is showed by home office. Consequently, the management team of superstore should provide more discounts to the home office segment so that, the good amount of profit will also generate.
